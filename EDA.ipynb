# %% [markdown]
#  AI Copilot was used to create code in this project. I modified when needed.

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/Users/ericpool/Documents/GitHub/sprint_4_project/vehicles_us.csv'
df = pd.read_csv(file_path)

plt.figure(figsize=(10, 6))
plt.hist(df['condition'], bins=50, edgecolor='k')
plt.title('Car Condition')
plt.xlabel('Condition')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
file_path = '/Users/ericpool/Documents/GitHub/sprint_4_project/vehicles_us.csv'
df = pd.read_csv(file_path)

plt.figure(figsize=(10, 6))
plt.hist(df['odometer'], bins=50, edgecolor='k')
plt.title('Car Odometer')
plt.xlabel('Odometer')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['type'], df['price'], alpha=0.5)
plt.title('Car Type')
plt.xlabel('Type')
plt.ylabel('Price')
plt.grid(True)
plt.show()
